# %%
import sys
sys.path.insert(1, "../modules")

# %%
import path
import get_data
import time
from datetime import date, timedelta

# %% [markdown]
# We are going to download every programme since 16/06/2013.
# Each time we download a program, we download the races associated.
# WAIT_TIME is here to be more discrete.

# %%
WAIT_TIME = .4

def handle_programme(date):
    programme = get_data.get_programme(date)
    if (programme == -1):
        return
    for reunion in programme["reunions"]:
        for course in reunion["courses"]:
            if (course["discipline"] == "PLAT"):
                get_data.get_course(date, reunion["numOfficiel"], course["numOrdre"])
                time.sleep(WAIT_TIME)

# %% [markdown]
# StackOverflowed code to iterate between two dates

# %%
def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %%
start_date = date(2014, 7, 5)
end_date = date.today()
for single_date in daterange(start_date, end_date):
    handle_programme(single_date.strftime("%d%m%Y"))
    time.sleep(WAIT_TIME)
# Out:
# Downloading race 05072014 R3 C3
# Downloading race 05072014 R3 C4
# Downloading race 05072014 R3 C5
# Downloading race 05072014 R3 C6
# Downloading race 05072014 R3 C7
# Downloading race 05072014 R3 C8
# Downloading race 05072014 R5 C5
# Downloading race 05072014 R5 C6
# Downloading race 05072014 R5 C7
# Downloading race 05072014 R5 C9
# Downloading race 05072014 R6 C5
# Downloading race 05072014 R7 C1
# Downloading race 05072014 R7 C2
# Downloading race 05072014 R7 C3
# Downloading race 05072014 R7 C4
# Downloading race 05072014 R7 C5
# Downloading race 05072014 R7 C6
# Downloading race 05072014 R7 C7
# Downloading race 05072014 R7 C8
# Downloading race 05072014 R7 C9
# Downloading race 05072014 R8 C2
# Downloading race 05072014 R8 C4
# Downloading programme 06072014
# Downloading race 06072014 R1 C1
# Downloading race 06072014 R1 C2
# Downloading race 06072014 R1 C3
# Downloading race 06072014 R1 C4
# Downloading race 06072014 R1 C5
# Downloading race 06072014 R1 C6
# Downloading race 06072014 R1 C7
# Downloading race 06072014 R1 C8
# Downloading race 06072014 R2 C1
# Downloading race 06072014 R2 C3
# Downloading race 06072014 R2 C4
# Downloading race 06072014 R2 C6
# Downloading race 06072014 R2 C7
# Downloading race 06072014 R2 C8
# Downloading race 06072014 R5 C1
# Downloading race 06072014 R5 C2
# Downloading race 06072014 R5 C3
# Downloading race 06072014 R6 C8
# Downloading programme 07072014
# Downloading race 07072014 R1 C1
# Downloading race 07072014 R1 C2
# Downloading race 07072014 R1 C3
# Downloading race 07072014 R1 C4
# Downloading race 07072014 R1 C5
# Downloading race 07072014 R1 C6
# Downloading race 07072014 R1 C7
# Downloading race 07072014 R1 C8
# Downloading race 07072014 R1 C9
# Downloading race 07072014 R4 C1
# Downloading race 07072014 R4 C2
# Downloading race 07072014 R4 C3
# Downloading race 07072014 R4 C4
# Downloading race 07072014 R4 C5
# Downloading programme 08072014
# Downloading race 08072014 R2 C1
# Downloading race 08072014 R2 C2
# Downloading race 08072014 R2 C3
# Downloading race 08072014 R2 C4
# Downloading race 08072014 R2 C5
# Downloading race 08072014 R2 C6
# Downloading race 08072014 R2 C7
# Downloading race 08072014 R2 C8
# Downloading race 08072014 R2 C9
# Downloading race 08072014 R3 C1
# Downloading race 08072014 R3 C2
# Downloading race 08072014 R3 C3
# Downloading race 08072014 R3 C4
# Downloading race 08072014 R3 C7
# Downloading race 08072014 R3 C8
# Downloading race 08072014 R5 C1
# Downloading race 08072014 R5 C2
# Downloading race 08072014 R5 C3
# Downloading race 08072014 R5 C4
# Downloading race 08072014 R5 C5
# Downloading race 08072014 R5 C6
# Downloading race 08072014 R5 C7
# Downloading race 08072014 R5 C8
# Downloading programme 09072014
# Downloading race 09072014 R2 C1
# Downloading race 09072014 R2 C2
# Downloading race 09072014 R2 C3
# Downloading race 09072014 R2 C4
# Downloading race 09072014 R2 C5
# Downloading race 09072014 R2 C6
# Downloading race 09072014 R2 C7
# Downloading race 09072014 R2 C8
# Downloading race 09072014 R4 C1
# Downloading race 09072014 R4 C2
# Downloading race 09072014 R4 C3
# Downloading race 09072014 R4 C4
# Downloading race 09072014 R4 C5
# Downloading race 09072014 R4 C6
# Downloading programme 10072014
# Downloading race 10072014 R1 C1
# Downloading race 10072014 R1 C2
# Downloading race 10072014 R1 C3
# Downloading race 10072014 R1 C4
# Downloading race 10072014 R1 C5
# Downloading race 10072014 R1 C6
# Downloading race 10072014 R1 C7
# Downloading race 10072014 R1 C8
# Downloading race 10072014 R4 C1
# Downloading race 10072014 R4 C2
# Downloading race 10072014 R4 C3
# Downloading race 10072014 R4 C4
# Downloading race 10072014 R4 C5
# Downloading race 10072014 R4 C6
# Downloading race 10072014 R4 C7
# Downloading race 10072014 R4 C8
# Downloading race 10072014 R5 C3
# Downloading programme 11072014
# Downloading race 11072014 R1 C1
# Downloading race 11072014 R1 C2
# Downloading race 11072014 R1 C3
# Downloading race 11072014 R1 C5
# Downloading race 11072014 R1 C6
# Downloading race 11072014 R1 C7
# Downloading race 11072014 R4 C1
# Downloading race 11072014 R4 C2
# Downloading race 11072014 R4 C3
# Downloading race 11072014 R4 C4
# Downloading race 11072014 R4 C5
# Downloading race 11072014 R4 C6
# Downloading race 11072014 R4 C7
# Downloading race 11072014 R6 C3
# Downloading programme 12072014
# Downloading race 12072014 R3 C4
# Downloading race 12072014 R3 C5
# Downloading race 12072014 R3 C6
# Downloading race 12072014 R3 C7
# Downloading race 12072014 R3 C8
# Downloading race 12072014 R5 C4
# Downloading race 12072014 R6 C1
# Downloading race 12072014 R6 C2
# Downloading race 12072014 R6 C3
# Downloading race 12072014 R6 C4
# Downloading race 12072014 R6 C5
# Downloading race 12072014 R6 C6
# Downloading race 12072014 R6 C7
# Downloading race 12072014 R6 C8
# Downloading race 12072014 R6 C9
# Downloading programme 13072014
# Downloading race 13072014 R1 C1
# Downloading race 13072014 R1 C2
# Downloading race 13072014 R1 C3
# Downloading race 13072014 R1 C4
