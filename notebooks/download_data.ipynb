# %%
import sys
sys.path.insert(1, "../modules")

# %%
import path
import get_data
import time
from datetime import date, timedelta

# %% [markdown]
# We are going to download every programme since 16/06/2013.
# Each time we download a program, we download the races associated.
# WAIT_TIME is here to be more discrete.

# %%
WAIT_TIME = .4

def handle_programme(date):
    programme = get_data.get_programme(date)
    if (programme == -1):
        return
    for reunion in programme["reunions"]:
        for course in reunion["courses"]:
            if (course["discipline"] == "PLAT"):
                get_data.get_course(date, reunion["numOfficiel"], course["numOrdre"])
                time.sleep(WAIT_TIME)

# %% [markdown]
# StackOverflowed code to iterate between two dates

# %%
def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %%
start_date = date(2013, 6, 16)
end_date = date.today()
for single_date in daterange(start_date, end_date):
    handle_programme(single_date.strftime("%d%m%Y"))
    time.sleep(WAIT_TIME)
# Out:
# Downloading programme 17062013
# Downloading race 17062013 R4 C2
# Downloading race 17062013 R4 C3
# Downloading race 17062013 R4 C4
# Downloading race 17062013 R4 C5
# Downloading race 17062013 R4 C6
# Downloading programme 18062013
# Downloading race 18062013 R1 C2
# Downloading race 18062013 R1 C4
# Downloading race 18062013 R1 C6
# Downloading race 18062013 R1 C8
# Downloading race 18062013 R1 C9
# Downloading race 18062013 R2 C1
# Downloading race 18062013 R2 C2
# Downloading race 18062013 R2 C3
# Downloading race 18062013 R2 C4
# Downloading race 18062013 R2 C5
# Downloading race 18062013 R2 C6
# Downloading race 18062013 R3 C1
# Downloading race 18062013 R3 C2
# Downloading race 18062013 R3 C3
# Downloading race 18062013 R3 C4
# Downloading race 18062013 R3 C5
# Downloading race 18062013 R3 C6
# Downloading race 18062013 R3 C7
# Downloading race 18062013 R3 C9
# Downloading race 18062013 R5 C1
# Downloading race 18062013 R5 C2
# Downloading race 18062013 R5 C3
# Downloading race 18062013 R5 C4
# Downloading programme 19062013
# Downloading race 19062013 R2 C1
# Downloading race 19062013 R2 C2
# Downloading race 19062013 R2 C3
# Downloading race 19062013 R2 C4
# Downloading race 19062013 R2 C5
# Downloading race 19062013 R2 C6
# Downloading race 19062013 R2 C7
# Downloading race 19062013 R2 C8
# Downloading race 19062013 R4 C1
# Downloading race 19062013 R4 C2
# Downloading race 19062013 R4 C3
# Downloading race 19062013 R4 C5
# Downloading programme 20062013
# Downloading race 20062013 R4 C1
# Downloading race 20062013 R4 C2
# Downloading race 20062013 R4 C3
# Downloading race 20062013 R4 C4
# Downloading race 20062013 R4 C5
# Downloading race 20062013 R4 C6
# Downloading race 20062013 R4 C7
# Downloading race 20062013 R4 C8
# Downloading race 20062013 R5 C1
# Downloading race 20062013 R5 C2
# Downloading race 20062013 R5 C3
# Downloading race 20062013 R5 C5
# Downloading race 20062013 R5 C6
# Downloading race 20062013 R6 C1
# Downloading race 20062013 R6 C2
# Downloading race 20062013 R6 C4
# Downloading programme 21062013
# Downloading race 21062013 R1 C1
# Downloading race 21062013 R1 C2
# Downloading race 21062013 R1 C3
# Downloading race 21062013 R1 C4
# Downloading race 21062013 R1 C5
# Downloading race 21062013 R1 C6
# Downloading race 21062013 R1 C7
# Downloading race 21062013 R1 C8
# Downloading race 21062013 R2 C1
# Downloading race 21062013 R2 C2
# Downloading race 21062013 R2 C3
# Downloading race 21062013 R2 C4
# Downloading race 21062013 R2 C5
# Downloading race 21062013 R2 C6
# Downloading race 21062013 R2 C7
# Downloading race 21062013 R2 C8
# Downloading race 21062013 R4 C1
# Downloading race 21062013 R4 C2
# Downloading race 21062013 R4 C3
# Downloading race 21062013 R4 C4
# Downloading race 21062013 R4 C5
# Downloading race 21062013 R4 C6
# Downloading race 21062013 R4 C7
# Downloading race 21062013 R6 C1
# Downloading race 21062013 R6 C2
# Downloading race 21062013 R6 C3
# Downloading race 21062013 R6 C4
# Downloading race 21062013 R6 C5
# Downloading programme 22062013
# Cannot download programme 22062013
# Downloading programme 23062013
# Downloading race 23062013 R1 C1
# Downloading race 23062013 R1 C2
# Downloading race 23062013 R1 C3
# Downloading race 23062013 R1 C4
# Downloading race 23062013 R1 C5
# Downloading race 23062013 R1 C6
# Downloading race 23062013 R1 C7
# Downloading race 23062013 R1 C8
# Downloading race 23062013 R1 C9
# Downloading race 23062013 R2 C3
# Downloading race 23062013 R2 C4
# Downloading race 23062013 R2 C5
# Downloading race 23062013 R2 C6
# Downloading race 23062013 R2 C7
# Downloading race 23062013 R4 C5
# Downloading race 23062013 R4 C6
# Downloading race 23062013 R4 C7
# Downloading programme 24062013
# Downloading race 24062013 R1 C1
# Downloading race 24062013 R1 C2
# Downloading race 24062013 R1 C3
# Downloading race 24062013 R1 C4
# Downloading race 24062013 R1 C5
# Downloading race 24062013 R1 C6
# Downloading race 24062013 R1 C7
# Downloading race 24062013 R1 C8
# Downloading race 24062013 R1 C9
# Downloading race 24062013 R4 C1
# Downloading race 24062013 R4 C2
# Downloading race 24062013 R4 C3
# Downloading race 24062013 R4 C4
# Downloading race 24062013 R4 C5
# Downloading race 24062013 R4 C6
# Downloading race 24062013 R7 C1
# Downloading race 24062013 R7 C3
# Downloading race 24062013 R7 C5
# Downloading programme 25062013
# Downloading race 25062013 R1 C1
# Downloading race 25062013 R1 C2
# Downloading race 25062013 R1 C3
# Downloading race 25062013 R1 C4
# Downloading race 25062013 R1 C5
# Downloading race 25062013 R1 C6
# Downloading race 25062013 R1 C7
# Downloading race 25062013 R1 C8
# Downloading programme 26062013
# Downloading race 26062013 R1 C1
# Downloading race 26062013 R1 C2
# Downloading race 26062013 R1 C3
# Downloading race 26062013 R1 C4
# Downloading race 26062013 R1 C5
# Downloading race 26062013 R1 C6
# Downloading race 26062013 R1 C7
# Downloading race 26062013 R1 C8
# Downloading race 26062013 R3 C1
# Downloading race 26062013 R3 C2
# Downloading race 26062013 R3 C3
# Downloading race 26062013 R3 C4
# Downloading race 26062013 R3 C6
# Downloading race 26062013 R3 C8
# Downloading race 26062013 R4 C2
# Downloading race 26062013 R4 C3
# Downloading race 26062013 R4 C4
# Downloading race 26062013 R4 C5
# Downloading race 26062013 R4 C6
# Downloading race 26062013 R4 C7
# Downloading programme 27062013
# Downloading race 27062013 R3 C1
# Downloading race 27062013 R3 C2
# Downloading race 27062013 R3 C3
# Downloading race 27062013 R3 C4
# Downloading race 27062013 R3 C5
# Downloading race 27062013 R3 C6
# Downloading race 27062013 R3 C7
# Downloading race 27062013 R3 C8
# Downloading race 27062013 R3 C9
# Downloading programme 28062013
# Downloading race 28062013 R1 C1
# Downloading race 28062013 R1 C2
# Downloading race 28062013 R1 C3
# Downloading race 28062013 R1 C4
# Downloading race 28062013 R1 C5
# Downloading race 28062013 R1 C6
# Downloading race 28062013 R7 C1
# Downloading race 28062013 R7 C3
# Downloading race 28062013 R7 C5
# Downloading programme 29062013
# Downloading race 29062013 R2 C1
# Downloading race 29062013 R2 C2
# Downloading race 29062013 R2 C3
# Downloading race 29062013 R2 C4
# Downloading race 29062013 R2 C5
# Downloading race 29062013 R2 C6
# Downloading race 29062013 R2 C7
# Downloading race 29062013 R2 C8
# Downloading race 29062013 R3 C1
# Downloading race 29062013 R3 C2
# Downloading race 29062013 R3 C3
# Downloading race 29062013 R3 C4
# Downloading race 29062013 R3 C6
# Downloading race 29062013 R5 C2
# Downloading race 29062013 R5 C5
# Downloading race 29062013 R5 C6
# Downloading race 29062013 R5 C7
# Downloading race 29062013 R8 C1
# Downloading race 29062013 R8 C2
# Downloading race 29062013 R8 C3
# Downloading race 29062013 R8 C4
# Downloading race 29062013 R8 C5
# Downloading race 29062013 R8 C6
# Downloading race 29062013 R8 C7
# Downloading race 29062013 R8 C8
# Downloading race 29062013 R10 C1
# Downloading race 29062013 R10 C2
# Downloading race 29062013 R10 C3
# Downloading race 29062013 R10 C4
# Downloading race 29062013 R10 C5
# Downloading programme 30062013
# Downloading race 30062013 R1 C1
# Downloading race 30062013 R1 C2
# Downloading race 30062013 R1 C3
# Downloading race 30062013 R1 C4
# Downloading race 30062013 R1 C5
# Downloading race 30062013 R1 C6
# Downloading race 30062013 R1 C7
# Downloading race 30062013 R1 C8
# Downloading race 30062013 R1 C9
# Downloading race 30062013 R2 C1
# Downloading race 30062013 R2 C2
# Downloading race 30062013 R2 C3
# Downloading race 30062013 R2 C4
# Downloading race 30062013 R2 C5
# Downloading race 30062013 R2 C6
# Downloading race 30062013 R2 C7
# Downloading race 30062013 R2 C8
# Downloading race 30062013 R5 C1
# Downloading race 30062013 R5 C2
# Downloading race 30062013 R5 C4
# Downloading race 30062013 R5 C7
# Downloading race 30062013 R6 C7
# Downloading programme 01072013
# Downloading race 01072013 R1 C1
# Downloading race 01072013 R1 C2
# Downloading race 01072013 R1 C3
# Downloading race 01072013 R1 C4
# Downloading race 01072013 R1 C5
# Downloading race 01072013 R1 C6
# Downloading race 01072013 R1 C7
# Downloading race 01072013 R1 C8
# Downloading race 01072013 R3 C1
# Downloading race 01072013 R3 C2
# Downloading race 01072013 R3 C3
# Downloading race 01072013 R3 C4
# Downloading race 01072013 R3 C5
# Downloading race 01072013 R3 C6
# Downloading race 01072013 R4 C1
# Downloading race 01072013 R4 C2
# Downloading race 01072013 R4 C3
# Downloading race 01072013 R4 C4
# Downloading race 01072013 R4 C5
# Downloading race 01072013 R4 C6
# Downloading race 01072013 R5 C3
# Downloading race 01072013 R5 C4
# Downloading race 01072013 R5 C5
# Downloading race 01072013 R5 C6
# Downloading race 01072013 R5 C7
# Downloading programme 02072013
# Downloading race 02072013 R1 C6
