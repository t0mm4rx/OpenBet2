# %%
import sys
sys.path.insert(1, "../modules")

# %%
import path
import get_data

# %% [markdown]
# Testing path

# %%
path.PATH
# Out:
# '/home/tom/programmation/python/OpenBet2/'

# %% [markdown]
# Testing functions to get data

# %%
programme = get_data.get_programme("07022020")
print(programme["reunions"][0]["courses"][0])
# Out:
# {'cached': False, 'arriveeDefinitive': True, 'departImminent': False, 'timezoneOffset': 3600000, 'numReunion': 1, 'numOrdre': 1, 'numExterne': 1, 'heureDepart': 1581075720000, 'libelle': 'PRIX DU LITTORAL', 'libelleCourt': 'DU LITTORAL', 'montantPrix': 19000, 'parcours': 'Grande piste', 'distance': 2400, 'distanceUnit': 'METRE', 'corde': 'CORDE_GAUCHE', 'discipline': 'PLAT', 'specialite': 'PLAT', 'categorieParticularite': 'COURSE_A_CONDITIONS', 'conditionAge': 'QUATRE_ANS_ET_PLUS', 'conditionSexe': 'TOUS_CHEVAUX', 'nombreDeclaresPartants': 6, 'grandPrixNationalTrot': False, 'numSocieteMere': 3263, 'pariMultiCourses': False, 'pariSpecial': False, 'montantTotalOffert': 19000, 'montantOffert1er': 9500, 'montantOffert2eme': 3800, 'montantOffert3eme': 2850, 'montantOffert4eme': 1900, 'montantOffert5eme': 950, 'conditions': "Pour chevaux entiers, hongres et jume nts de 4 ans et au-dessus, n'ayant pa s, depuis le 1er mars 2019 inclus, re çu une allocation de 12.000 (Handicap s exceptés). Poids : 4 ans, 56 k.1/2 ; 5 ans et au-dessus, 57 k.1/2. Surch arges accumulées pour les sommes reçu es en victoires et places depuis le 1 er juin 2019 inclus : 1 k. par 5.000 reçus.", 'numCourseDedoublee': 0, 'paris': [{'spotAutorise': False, 'codePari': 'SIMPLE_GAGNANT', 'complement': False, 'ordre': False, 'nbChevauxReglementaire': 1, 'combine': False, 'typePari': 'SIMPLE_GAGNANT', 'miseBase': 150, 'enVente': False, 'audience': 'NATIONAL', 'reportable': True, 'infosJackpot': {'miseBase': 200, 'tauxContribution': 25}}, {'spotAutorise': False, 'codePari': 'E_SIMPLE_GAGNANT', 'complement': False, 'ordre': False, 'nbChevauxReglementaire': 1, 'combine': False, 'typePari': 'E_SIMPLE_GAGNANT', 'miseBase': 150, 'enVente': False, 'audience': 'NATIONAL', 'reportable': True, 'infosJackpot': {'miseBase': 200, 'tauxContribution': 25}}, {'spotAutorise': False, 'codePari': 'SIMPLE_PLACE', 'complement': False, 'ordre': False, 'nbChevauxReglementaire': 1, 'combine': False, 'typePari': 'SIMPLE_PLACE', 'miseBase': 150, 'enVente': False, 'audience': 'NATIONAL', 'reportable': True, 'infosJackpot': {'miseBase': 200, 'tauxContribution': 25}}, {'spotAutorise': False, 'codePari': 'E_SIMPLE_PLACE', 'complement': False, 'ordre': False, 'nbChevauxReglementaire': 1, 'combine': False, 'typePari': 'E_SIMPLE_PLACE', 'miseBase': 150, 'enVente': False, 'audience': 'NATIONAL', 'reportable': True, 'infosJackpot': {'miseBase': 200, 'tauxContribution': 25}}, {'spotAutorise': False, 'codePari': 'REPORT_PLUS', 'complement': False, 'ordre': False, 'nbChevauxReglementaire': 1, 'combine': False, 'typePari': 'REPORT_PLUS', 'enVente': False, 'reportable': False}, {'spotAutorise': False, 'codePari': 'E_REPORT_PLUS', 'complement': False, 'ordre': False, 'nbChevauxReglementaire': 1, 'combine': False, 'typePari': 'E_REPORT_PLUS', 'enVente': False, 'reportable': False}, {'spotAutorise': True, 'codePari': 'COUPLE_ORDRE', 'complement': True, 'ordre': True, 'nbChevauxReglementaire': 2, 'combine': True, 'valeursFlexiAutorisees': [50], 'typePari': 'COUPLE_ORDRE', 'miseBase': 150, 'enVente': False, 'audience': 'NATIONAL', 'reportable': False}, {'spotAutorise': True, 'codePari': 'E_COUPLE_ORDRE', 'complement': True, 'ordre': True, 'nbChevauxReglementaire': 2, 'combine': True, 'valeursFlexiAutorisees': [50], 'typePari': 'E_COUPLE_ORDRE', 'miseBase': 150, 'enVente': False, 'audience': 'NATIONAL', 'reportable': False}, {'spotAutorise': True, 'codePari': 'TRIO_ORDRE', 'complement': True, 'ordre': True, 'nbChevauxReglementaire': 3, 'combine': True, 'valeursFlexiAutorisees': [50], 'typePari': 'TRIO_ORDRE', 'miseBase': 150, 'enVente': False, 'audience': 'NATIONAL', 'reportable': False}, {'spotAutorise': True, 'codePari': 'E_TRIO_ORDRE', 'complement': True, 'ordre': True, 'nbChevauxReglementaire': 3, 'combine': True, 'valeursFlexiAutorisees': [50], 'typePari': 'E_TRIO_ORDRE', 'miseBase': 150, 'enVente': False, 'audience': 'NATIONAL', 'reportable': False}, {'spotAutorise': True, 'codePari': 'SUPER_QUATRE', 'compl ...

# %%
get_data.get_participants("07022020", 1, 1)
# Out:
# {'participants': [{'nom': "REBEL D'ANS",
#    'numPmu': 1,
#    'age': 5,
#    'sexe': 'HONGRES',
#    'race': 'PUR-SANG',
#    'statut': 'PARTANT',
#    'placeCorde': 3,
#    'oeilleres': 'SANS_OEILLERES',
#    'proprietaire': 'A.PHILIPPOT',
#    'entraineur': 'C.ESCUDER',
#    'driver': 'E.CIESLIK',
#    'driverChange': False,
#    'robe': {'code': '001', 'libelleCourt': 'ALEZAN', 'libelleLong': 'ALEZAN'},
#    'indicateurInedit': False,
#    'musique': '2p(19)1p2p4p1p2p8p5p5p',
#    'nombreCourses': 30,
#    'nombreVictoires': 4,
#    'nombrePlaces': 16,
#    'nombrePlacesSecond': 6,
#    'nombrePlacesTroisieme': 4,
#    'gainsParticipant': {'gainsCarriere': 8680000,
#     'gainsVictoires': 4050000,
#     'gainsPlace': 4630000,
#     'gainsAnneeEnCours': 400000,
#     'gainsAnneePrecedente': 2760000},
#    'handicapValeur': 38.0,
#    'nomPere': 'Legolas',
#    'nomMere': 'Hermei',
#    'nomPereMere': 'Snurge',
#    'ordreArrivee': 5,
#    'jumentPleine': False,
#    'engagement': False,
#    'supplement': 0,
#    'handicapPoids': 635,
#    'poidsConditionMonte': 620,
#    'poidsConditionMonteChange': False,
#    'distanceChevalPrecedent': {'libelleCourt': '6 L 1/2',
#     'libelleLong': '6 longueurs 1/2',
#     'code': 38,
#     'identifiant': 'SIX_LONGUEURS_ET_DEMIE'},
#    'dernierRapportDirect': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 9.5,
#     'typeRapport': 'DIRECT',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075775000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 1},
#    'dernierRapportReference': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 10.0,
#     'typeRapport': 'REFERENCE',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075005000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 1},
#    'urlCasaque': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/P1.png',
#    'commentaireApresCourse': {'texte': "Après avoir relayé en tête Chouain (4), n'a pu contrer les assauts dès l'entrée de ligne droite, avant de rentrer progressivement dans le rang.",
#     'source': 'GENY'},
#    'eleveur': "SCEA D'ANS",
#    'allure': 'GALOP'},
#   {'nom': 'BLUE BLUE EYES',
#    'numPmu': 2,
#    'age': 5,
#    'sexe': 'HONGRES',
#    'race': 'PUR-SANG',
#    'statut': 'PARTANT',
#    'placeCorde': 2,
#    'oeilleres': 'SANS_OEILLERES',
#    'proprietaire': 'A.DELAEY',
#    'entraineur': 'JC.ROUGET (S)',
#    'driver': 'C.PACAUT',
#    'driverChange': False,
#    'robe': {'code': '020', 'libelleCourt': 'BAI', 'libelleLong': 'BAI'},
#    'indicateurInedit': False,
#    'musique': '4p(19)1p1p1p1pTs4s(18)1h',
#    'nombreCourses': 11,
#    'nombreVictoires': 7,
#    'nombrePlaces': 3,
#    'nombrePlacesSecond': 0,
#    'nombrePlacesTroisieme': 1,
#    'gainsParticipant': {'gainsCarriere': 6863000,
#     'gainsVictoires': 5825000,
#     'gainsPlace': 1038000,
#     'gainsAnneeEnCours': 180000,
#     'gainsAnneePrecedente': 1975000},
#    'handicapValeur': 40.5,
#    'nomPere': 'Sageburg',
#    'nomMere': 'Blue hollow',
#    'nomPereMere': 'Beat hollow',
#    'ordreArrivee': 4,
#    'jumentPleine': False,
#    'engagement': False,
#    'supplement': 0,
#    'handicapPoids': 615,
#    'poidsConditionMonte': 600,
#    'poidsConditionMonteChange': False,
#    'distanceChevalPrecedent': {'libelleCourt': '1 L',
#     'libelleLong': '1 longueur',
#     'code': 1,
#     'identifiant': 'UNE_LONGUEUR'},
#    'dernierRapportDirect': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 4.2,
#     'typeRapport': 'DIRECT',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075775000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 2},
#    'dernierRapportReference': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 4.3,
#     'typeRapport': 'REFERENCE',
#     'indicateurTendance': '+',
#     'nombreIndicateurTendance': 2.38,
#     'dateRapport': 1581075005000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 2},
#    'urlCasaque': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/P2.png',
#    'commentaireApresCourse': {'texte': "Rapidement placé dans le dos de l'animateur, Rebel d'Ans (1), a lutté, en vain, pour la troisième place avec Golden Wood (3) dans la phase finale.",
#     'source': 'GENY'},
#    'eleveur': 'MR PHILIPPE DELAEY',
#    'allure': 'GALOP'},
#   {'nom': 'GOLDEN WOOD',
#    'numPmu': 3,
#    'age': 10,
#    'sexe': 'HONGRES',
#    'race': 'PUR-SANG',
#    'statut': 'PARTANT',
#    'placeCorde': 5,
#    'oeilleres': 'SANS_OEILLERES',
#    'proprietaire': 'MME C.WINGTANS',
#    'entraineur': 'N.CAULLERY',
#    'driver': 'C.SOUMILLON',
#    'driverChange': False,
#    'robe': {'code': '001', 'libelleCourt': 'ALEZAN', 'libelleLong': 'ALEZAN'},
#    'indicateurInedit': False,
#    'musique': '(18)9p2p1p(17)2p1p1p(16)4p',
#    'nombreCourses': 37,
#    'nombreVictoires': 11,
#    'nombrePlaces': 22,
#    'nombrePlacesSecond': 7,
#    'nombrePlacesTroisieme': 3,
#    'gainsParticipant': {'gainsCarriere': 40673000,
#     'gainsVictoires': 28119800,
#     'gainsPlace': 12553200,
#     'gainsAnneeEnCours': 0,
#     'gainsAnneePrecedente': 0},
#    'nomPere': 'Gold away',
#    'nomMere': 'Twisting',
#    'nomPereMere': 'Pivotal',
#    'ordreArrivee': 3,
#    'jumentPleine': False,
#    'engagement': False,
#    'supplement': 0,
#    'handicapPoids': 575,
#    'poidsConditionMonteChange': False,
#    'distanceChevalPrecedent': {'libelleCourt': '2 L',
#     'libelleLong': '2 longueurs',
#     'code': 10,
#     'identifiant': 'DEUX_LONGUEURS'},
#    'dernierRapportDirect': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 3.2,
#     'typeRapport': 'DIRECT',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075775000,
#     'permutation': 1,
#     'favoris': True,
#     'numPmu1': 3},
#    'dernierRapportReference': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 2.3,
#     'typeRapport': 'REFERENCE',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075005000,
#     'permutation': 1,
#     'favoris': True,
#     'numPmu1': 3},
#    'urlCasaque': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/P3.png',
#    'commentaireApresCourse': {'texte': "En position d'attente, en cinquième position, a suivi la progression de Chouain (4) dans la ligne droite et s'est bien comporté jusqu'au bout, en retrait des deux premiers.",
#     'source': 'GENY'},
#    'eleveur': 'MR JO AWOUTERS',
#    'allure': 'GALOP'},
#   {'nom': 'CHOUAIN',
#    'numPmu': 4,
#    'age': 4,
#    'sexe': 'HONGRES',
#    'race': 'PUR-SANG',
#    'statut': 'PARTANT',
#    'placeCorde': 6,
#    'oeilleres': 'SANS_OEILLERES',
#    'proprietaire': 'STALL BIG JUMP & FRIENDS',
#    'entraineur': 'M.RULEC',
#    'driver': 'A.HAMELIN',
#    'driverChange': False,
#    'robe': {'code': '040', 'libelleCourt': 'GRIS', 'libelleLong': 'GRIS'},
#    'indicateurInedit': False,
#    'musique': '3p(19)2p5p1p8p5p(18)1p2p',
#    'nombreCourses': 11,
#    'nombreVictoires': 2,
#    'nombrePlaces': 5,
#    'nombrePlacesSecond': 2,
#    'nombrePlacesTroisieme': 1,
#    'gainsParticipant': {'gainsCarriere': 3889000,
#     'gainsVictoires': 1900000,
#     'gainsPlace': 1989000,
#     'gainsAnneeEnCours': 285000,
#     'gainsAnneePrecedente': 2524000},
#    'handicapValeur': 41.0,
#    'nomPere': 'Rajsaman',
#    'nomMere': 'Our dream queen',
#    'nomPereMere': 'Oasis dream',
#    'ordreArrivee': 1,
#    'jumentPleine': False,
#    'engagement': False,
#    'supplement': 0,
#    'handicapPoids': 565,
#    'poidsConditionMonteChange': False,
#    'dernierRapportDirect': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 3.8,
#     'typeRapport': 'DIRECT',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075775000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 4},
#    'dernierRapportReference': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 4.7,
#     'typeRapport': 'REFERENCE',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075005000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 4},
#    'urlCasaque': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/P4.png',
#    'commentaireApresCourse': {'texte': "Relayé en tête par Rebel d'Ans (1), a patienté en troisième position, puis s'est annoncé en pleine piste, à l'entrée de ligne droite, et s'est montré le plus fort à la lutte.",
#     'source': 'GENY'},
#    'eleveur': 'FRANKLIN FINANCE S.A.',
#    'allure': 'GALOP'},
#   {'nom': 'BELLARIVA',
#    'numPmu': 5,
#    'age': 4,
#    'sexe': 'FEMELLES',
#    'race': 'PUR-SANG',
#    'statut': 'PARTANT',
#    'placeCorde': 4,
#    'oeilleres': 'SANS_OEILLERES',
#    'proprietaire': 'LG BLOODSTOCK',
#    'entraineur': 'C.FERLAND (S)',
#    'driver': 'S. PASQUIER',
#    'driverChange': False,
#    'robe': {'code': '020', 'libelleCourt': 'BAI', 'libelleLong': 'BAI'},
#    'indicateurInedit': False,
#    'musique': '1p(19)9p0p0p3p1p(18)6p',
#    'nombreCourses': 7,
#    'nombreVictoires': 2,
#    'nombrePlaces': 1,
#    'nombrePlacesSecond': 0,
#    'nombrePlacesTroisieme': 1,
#    'gainsParticipant': {'gainsCarriere': 2492000,
#     'gainsVictoires': 2100000,
#     'gainsPlace': 392000,
#     'gainsAnneeEnCours': 950000,
#     'gainsAnneePrecedente': 1542000},
#    'handicapValeur': 37.0,
#    'nomPere': 'Myboycharlie',
#    'nomMere': 'Lady millon',
#    'nomPereMere': 'Kheleyf',
#    'ordreArrivee': 2,
#    'jumentPleine': False,
#    'engagement': False,
#    'supplement': 0,
#    'handicapPoids': 560,
#    'poidsConditionMonteChange': False,
#    'distanceChevalPrecedent': {'libelleCourt': 'ENCOLURE',
#     'libelleLong': 'Encolure',
#     'code': 26,
#     'identifiant': 'ENCOLURE'},
#    'dernierRapportDirect': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 4.1,
#     'typeRapport': 'DIRECT',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075775000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 5},
#    'dernierRapportReference': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 6.8,
#     'typeRapport': 'REFERENCE',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075005000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 5},
#    'urlCasaque': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/P5.png',
#    'commentaireApresCourse': {'texte': "Toujours aux avant-postes, a pris le meilleur à mi-ligne droite, mais n'a pu endiguer l'attaque de Chouain (4) aux abords du poteau.",
#     'source': 'GENY'},
#    'eleveur': 'MR GERARD LABOUREAU',
#    'allure': 'GALOP'},
#   {'nom': 'GARLIGUETTE',
#    'numPmu': 6,
#    'age': 4,
#    'sexe': 'FEMELLES',
#    'race': 'PUR-SANG',
#    'statut': 'PARTANT',
#    'placeCorde': 1,
#    'oeilleres': 'SANS_OEILLERES',
#    'proprietaire': 'MME C.BARANDE BARBE',
#    'entraineur': 'MME C.BARANDE BARBE',
#    'driver': 'M.EON',
#    'driverChange': False,
#    'robe': {'code': '020', 'libelleCourt': 'BAI', 'libelleLong': 'BAI'},
#    'indicateurInedit': False,
#    'musique': '(19)7p',
#    'nombreCourses': 1,
#    'nombreVictoires': 0,
#    'nombrePlaces': 1,
#    'nombrePlacesSecond': 0,
#    'nombrePlacesTroisieme': 0,
#    'gainsParticipant': {'gainsCarriere': 70000,
#     'gainsVictoires': 0,
#     'gainsPlace': 70000,
#     'gainsAnneeEnCours': 0,
#     'gainsAnneePrecedente': 70000},
#    'nomPere': 'Linngari',
#    'nomMere': 'Garlinote',
#    'nomPereMere': 'Poliglote',
#    'ordreArrivee': 6,
#    'jumentPleine': False,
#    'engagement': False,
#    'supplement': 0,
#    'handicapPoids': 550,
#    'poidsConditionMonte': 535,
#    'poidsConditionMonteChange': False,
#    'distanceChevalPrecedent': {'libelleCourt': '7 L',
#     'libelleLong': '7 longueurs',
#     'code': 17,
#     'identifiant': 'SEPT_LONGUEURS'},
#    'dernierRapportDirect': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 31.0,
#     'typeRapport': 'DIRECT',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075775000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 6},
#    'dernierRapportReference': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 16.0,
#     'typeRapport': 'REFERENCE',
#     'indicateurTendance': '-',
#     'nombreIndicateurTendance': -1.17,
#     'dateRapport': 1581075005000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 6},
#    'urlCasaque': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/P6.png',
#    'commentaireApresCourse': {'texte': "Toujours à l'arrière-garde, a été lâchée dès l'entrée de la ligne droite.",
#     'source': 'GENY'},
#    'eleveur': 'MME CORINE BARANDE BARBE',
#    'allure': 'GALOP'}],
#  'ecuries': [],
#  'spriteCasaques': [{'heightSize': 19,
#    'url': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/sprite_casaques_19px_size.png',
#    'originalSize': False},
#   {'heightSize': 40,
#    'url': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/sprite_casaques_40px_size.png',
#    'originalSize': False},
#   {'heightSize': 261,
#    'url': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/sprite_casaques_original_size.png',
#    'originalSize': True}],
#  'cached': False}

# %%
get_data.get_course("07022020", 1, 1)
# Out:
# {'finish': True,
#  'horses': [{'nom': "REBEL D'ANS",
#    'numPmu': 1,
#    'age': 5,
#    'sexe': 'HONGRES',
#    'race': 'PUR-SANG',
#    'statut': 'PARTANT',
#    'placeCorde': 3,
#    'oeilleres': 'SANS_OEILLERES',
#    'proprietaire': 'A.PHILIPPOT',
#    'entraineur': 'C.ESCUDER',
#    'driver': 'E.CIESLIK',
#    'driverChange': False,
#    'robe': {'code': '001', 'libelleCourt': 'ALEZAN', 'libelleLong': 'ALEZAN'},
#    'indicateurInedit': False,
#    'musique': '2p(19)1p2p4p1p2p8p5p5p',
#    'nombreCourses': 30,
#    'nombreVictoires': 4,
#    'nombrePlaces': 16,
#    'nombrePlacesSecond': 6,
#    'nombrePlacesTroisieme': 4,
#    'gainsParticipant': {'gainsCarriere': 8680000,
#     'gainsVictoires': 4050000,
#     'gainsPlace': 4630000,
#     'gainsAnneeEnCours': 400000,
#     'gainsAnneePrecedente': 2760000},
#    'handicapValeur': 38.0,
#    'nomPere': 'Legolas',
#    'nomMere': 'Hermei',
#    'nomPereMere': 'Snurge',
#    'ordreArrivee': 5,
#    'jumentPleine': False,
#    'engagement': False,
#    'supplement': 0,
#    'handicapPoids': 635,
#    'poidsConditionMonte': 620,
#    'poidsConditionMonteChange': False,
#    'distanceChevalPrecedent': {'libelleCourt': '6 L 1/2',
#     'libelleLong': '6 longueurs 1/2',
#     'code': 38,
#     'identifiant': 'SIX_LONGUEURS_ET_DEMIE'},
#    'dernierRapportDirect': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 9.5,
#     'typeRapport': 'DIRECT',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075775000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 1},
#    'dernierRapportReference': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 10.0,
#     'typeRapport': 'REFERENCE',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075005000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 1},
#    'urlCasaque': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/P1.png',
#    'commentaireApresCourse': {'texte': "Après avoir relayé en tête Chouain (4), n'a pu contrer les assauts dès l'entrée de ligne droite, avant de rentrer progressivement dans le rang.",
#     'source': 'GENY'},
#    'eleveur': "SCEA D'ANS",
#    'allure': 'GALOP'},
#   {'nom': 'BLUE BLUE EYES',
#    'numPmu': 2,
#    'age': 5,
#    'sexe': 'HONGRES',
#    'race': 'PUR-SANG',
#    'statut': 'PARTANT',
#    'placeCorde': 2,
#    'oeilleres': 'SANS_OEILLERES',
#    'proprietaire': 'A.DELAEY',
#    'entraineur': 'JC.ROUGET (S)',
#    'driver': 'C.PACAUT',
#    'driverChange': False,
#    'robe': {'code': '020', 'libelleCourt': 'BAI', 'libelleLong': 'BAI'},
#    'indicateurInedit': False,
#    'musique': '4p(19)1p1p1p1pTs4s(18)1h',
#    'nombreCourses': 11,
#    'nombreVictoires': 7,
#    'nombrePlaces': 3,
#    'nombrePlacesSecond': 0,
#    'nombrePlacesTroisieme': 1,
#    'gainsParticipant': {'gainsCarriere': 6863000,
#     'gainsVictoires': 5825000,
#     'gainsPlace': 1038000,
#     'gainsAnneeEnCours': 180000,
#     'gainsAnneePrecedente': 1975000},
#    'handicapValeur': 40.5,
#    'nomPere': 'Sageburg',
#    'nomMere': 'Blue hollow',
#    'nomPereMere': 'Beat hollow',
#    'ordreArrivee': 4,
#    'jumentPleine': False,
#    'engagement': False,
#    'supplement': 0,
#    'handicapPoids': 615,
#    'poidsConditionMonte': 600,
#    'poidsConditionMonteChange': False,
#    'distanceChevalPrecedent': {'libelleCourt': '1 L',
#     'libelleLong': '1 longueur',
#     'code': 1,
#     'identifiant': 'UNE_LONGUEUR'},
#    'dernierRapportDirect': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 4.2,
#     'typeRapport': 'DIRECT',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075775000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 2},
#    'dernierRapportReference': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 4.3,
#     'typeRapport': 'REFERENCE',
#     'indicateurTendance': '+',
#     'nombreIndicateurTendance': 2.38,
#     'dateRapport': 1581075005000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 2},
#    'urlCasaque': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/P2.png',
#    'commentaireApresCourse': {'texte': "Rapidement placé dans le dos de l'animateur, Rebel d'Ans (1), a lutté, en vain, pour la troisième place avec Golden Wood (3) dans la phase finale.",
#     'source': 'GENY'},
#    'eleveur': 'MR PHILIPPE DELAEY',
#    'allure': 'GALOP'},
#   {'nom': 'GOLDEN WOOD',
#    'numPmu': 3,
#    'age': 10,
#    'sexe': 'HONGRES',
#    'race': 'PUR-SANG',
#    'statut': 'PARTANT',
#    'placeCorde': 5,
#    'oeilleres': 'SANS_OEILLERES',
#    'proprietaire': 'MME C.WINGTANS',
#    'entraineur': 'N.CAULLERY',
#    'driver': 'C.SOUMILLON',
#    'driverChange': False,
#    'robe': {'code': '001', 'libelleCourt': 'ALEZAN', 'libelleLong': 'ALEZAN'},
#    'indicateurInedit': False,
#    'musique': '(18)9p2p1p(17)2p1p1p(16)4p',
#    'nombreCourses': 37,
#    'nombreVictoires': 11,
#    'nombrePlaces': 22,
#    'nombrePlacesSecond': 7,
#    'nombrePlacesTroisieme': 3,
#    'gainsParticipant': {'gainsCarriere': 40673000,
#     'gainsVictoires': 28119800,
#     'gainsPlace': 12553200,
#     'gainsAnneeEnCours': 0,
#     'gainsAnneePrecedente': 0},
#    'nomPere': 'Gold away',
#    'nomMere': 'Twisting',
#    'nomPereMere': 'Pivotal',
#    'ordreArrivee': 3,
#    'jumentPleine': False,
#    'engagement': False,
#    'supplement': 0,
#    'handicapPoids': 575,
#    'poidsConditionMonteChange': False,
#    'distanceChevalPrecedent': {'libelleCourt': '2 L',
#     'libelleLong': '2 longueurs',
#     'code': 10,
#     'identifiant': 'DEUX_LONGUEURS'},
#    'dernierRapportDirect': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 3.2,
#     'typeRapport': 'DIRECT',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075775000,
#     'permutation': 1,
#     'favoris': True,
#     'numPmu1': 3},
#    'dernierRapportReference': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 2.3,
#     'typeRapport': 'REFERENCE',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075005000,
#     'permutation': 1,
#     'favoris': True,
#     'numPmu1': 3},
#    'urlCasaque': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/P3.png',
#    'commentaireApresCourse': {'texte': "En position d'attente, en cinquième position, a suivi la progression de Chouain (4) dans la ligne droite et s'est bien comporté jusqu'au bout, en retrait des deux premiers.",
#     'source': 'GENY'},
#    'eleveur': 'MR JO AWOUTERS',
#    'allure': 'GALOP'},
#   {'nom': 'CHOUAIN',
#    'numPmu': 4,
#    'age': 4,
#    'sexe': 'HONGRES',
#    'race': 'PUR-SANG',
#    'statut': 'PARTANT',
#    'placeCorde': 6,
#    'oeilleres': 'SANS_OEILLERES',
#    'proprietaire': 'STALL BIG JUMP & FRIENDS',
#    'entraineur': 'M.RULEC',
#    'driver': 'A.HAMELIN',
#    'driverChange': False,
#    'robe': {'code': '040', 'libelleCourt': 'GRIS', 'libelleLong': 'GRIS'},
#    'indicateurInedit': False,
#    'musique': '3p(19)2p5p1p8p5p(18)1p2p',
#    'nombreCourses': 11,
#    'nombreVictoires': 2,
#    'nombrePlaces': 5,
#    'nombrePlacesSecond': 2,
#    'nombrePlacesTroisieme': 1,
#    'gainsParticipant': {'gainsCarriere': 3889000,
#     'gainsVictoires': 1900000,
#     'gainsPlace': 1989000,
#     'gainsAnneeEnCours': 285000,
#     'gainsAnneePrecedente': 2524000},
#    'handicapValeur': 41.0,
#    'nomPere': 'Rajsaman',
#    'nomMere': 'Our dream queen',
#    'nomPereMere': 'Oasis dream',
#    'ordreArrivee': 1,
#    'jumentPleine': False,
#    'engagement': False,
#    'supplement': 0,
#    'handicapPoids': 565,
#    'poidsConditionMonteChange': False,
#    'dernierRapportDirect': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 3.8,
#     'typeRapport': 'DIRECT',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075775000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 4},
#    'dernierRapportReference': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 4.7,
#     'typeRapport': 'REFERENCE',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075005000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 4},
#    'urlCasaque': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/P4.png',
#    'commentaireApresCourse': {'texte': "Relayé en tête par Rebel d'Ans (1), a patienté en troisième position, puis s'est annoncé en pleine piste, à l'entrée de ligne droite, et s'est montré le plus fort à la lutte.",
#     'source': 'GENY'},
#    'eleveur': 'FRANKLIN FINANCE S.A.',
#    'allure': 'GALOP'},
#   {'nom': 'BELLARIVA',
#    'numPmu': 5,
#    'age': 4,
#    'sexe': 'FEMELLES',
#    'race': 'PUR-SANG',
#    'statut': 'PARTANT',
#    'placeCorde': 4,
#    'oeilleres': 'SANS_OEILLERES',
#    'proprietaire': 'LG BLOODSTOCK',
#    'entraineur': 'C.FERLAND (S)',
#    'driver': 'S. PASQUIER',
#    'driverChange': False,
#    'robe': {'code': '020', 'libelleCourt': 'BAI', 'libelleLong': 'BAI'},
#    'indicateurInedit': False,
#    'musique': '1p(19)9p0p0p3p1p(18)6p',
#    'nombreCourses': 7,
#    'nombreVictoires': 2,
#    'nombrePlaces': 1,
#    'nombrePlacesSecond': 0,
#    'nombrePlacesTroisieme': 1,
#    'gainsParticipant': {'gainsCarriere': 2492000,
#     'gainsVictoires': 2100000,
#     'gainsPlace': 392000,
#     'gainsAnneeEnCours': 950000,
#     'gainsAnneePrecedente': 1542000},
#    'handicapValeur': 37.0,
#    'nomPere': 'Myboycharlie',
#    'nomMere': 'Lady millon',
#    'nomPereMere': 'Kheleyf',
#    'ordreArrivee': 2,
#    'jumentPleine': False,
#    'engagement': False,
#    'supplement': 0,
#    'handicapPoids': 560,
#    'poidsConditionMonteChange': False,
#    'distanceChevalPrecedent': {'libelleCourt': 'ENCOLURE',
#     'libelleLong': 'Encolure',
#     'code': 26,
#     'identifiant': 'ENCOLURE'},
#    'dernierRapportDirect': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 4.1,
#     'typeRapport': 'DIRECT',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075775000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 5},
#    'dernierRapportReference': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 6.8,
#     'typeRapport': 'REFERENCE',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075005000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 5},
#    'urlCasaque': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/P5.png',
#    'commentaireApresCourse': {'texte': "Toujours aux avant-postes, a pris le meilleur à mi-ligne droite, mais n'a pu endiguer l'attaque de Chouain (4) aux abords du poteau.",
#     'source': 'GENY'},
#    'eleveur': 'MR GERARD LABOUREAU',
#    'allure': 'GALOP'},
#   {'nom': 'GARLIGUETTE',
#    'numPmu': 6,
#    'age': 4,
#    'sexe': 'FEMELLES',
#    'race': 'PUR-SANG',
#    'statut': 'PARTANT',
#    'placeCorde': 1,
#    'oeilleres': 'SANS_OEILLERES',
#    'proprietaire': 'MME C.BARANDE BARBE',
#    'entraineur': 'MME C.BARANDE BARBE',
#    'driver': 'M.EON',
#    'driverChange': False,
#    'robe': {'code': '020', 'libelleCourt': 'BAI', 'libelleLong': 'BAI'},
#    'indicateurInedit': False,
#    'musique': '(19)7p',
#    'nombreCourses': 1,
#    'nombreVictoires': 0,
#    'nombrePlaces': 1,
#    'nombrePlacesSecond': 0,
#    'nombrePlacesTroisieme': 0,
#    'gainsParticipant': {'gainsCarriere': 70000,
#     'gainsVictoires': 0,
#     'gainsPlace': 70000,
#     'gainsAnneeEnCours': 0,
#     'gainsAnneePrecedente': 70000},
#    'nomPere': 'Linngari',
#    'nomMere': 'Garlinote',
#    'nomPereMere': 'Poliglote',
#    'ordreArrivee': 6,
#    'jumentPleine': False,
#    'engagement': False,
#    'supplement': 0,
#    'handicapPoids': 550,
#    'poidsConditionMonte': 535,
#    'poidsConditionMonteChange': False,
#    'distanceChevalPrecedent': {'libelleCourt': '7 L',
#     'libelleLong': '7 longueurs',
#     'code': 17,
#     'identifiant': 'SEPT_LONGUEURS'},
#    'dernierRapportDirect': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 31.0,
#     'typeRapport': 'DIRECT',
#     'indicateurTendance': ' ',
#     'nombreIndicateurTendance': 0.0,
#     'dateRapport': 1581075775000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 6},
#    'dernierRapportReference': {'typePari': 'SIMPLE_GAGNANT',
#     'rapport': 16.0,
#     'typeRapport': 'REFERENCE',
#     'indicateurTendance': '-',
#     'nombreIndicateurTendance': -1.17,
#     'dateRapport': 1581075005000,
#     'permutation': 1,
#     'favoris': False,
#     'numPmu1': 6},
#    'urlCasaque': 'https://turfinfo.pmucdn.fr/casaques/07022020/R1/C1/P6.png',
#    'commentaireApresCourse': {'texte': "Toujours à l'arrière-garde, a été lâchée dès l'entrée de la ligne droite.",
#     'source': 'GENY'},
#    'eleveur': 'MME CORINE BARANDE BARBE',
#    'allure': 'GALOP'}],
#  'result': [4, 5, 3, 2, 1, 6]}
