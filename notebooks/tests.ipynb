# %%
import sys
sys.path.insert(1, "../modules")

# %%
import path
import get_data

# %% [markdown]
# Testing path

# %%
path.PATH
# Out:
# '/home/tom/programmation/python/OpenBet2/'

# %% [markdown]
# Testing functions to get data

# %%
programme = get_data.get_programme("07022020")
print(programme)
programme["reunions"][0]["courses"][0]
# Out:
# {'programme': {'cached': False, 'date': 1581030000000, 'dateProgrammeActif': 1581202800000, 'timezoneOffset': 3600000, 'reunions': [{'cached': False, 'timezoneOffset': 3600000, 'dateReunion': 1581030000000, 'numOfficiel': 1, 'numOfficielReunionPrecedente': None, 'numOfficielReunionSuivante': 2, 'numExterne': 1, 'nature': 'DIURNE', 'hippodrome': {'code': 'CAG', 'libelleCourt': 'CAGNES/MER', 'libelleLong': 'HIPPODROME DE CAGNES/MER'}, 'pays': {'code': 'FRA', 'libelle': 'FRANCE'}, 'courses': [{'cached': False, 'arriveeDefinitive': True, 'departImminent': False, 'timezoneOffset': 3600000, 'numReunion': 1, 'numOrdre': 1, 'numExterne': 1, 'heureDepart': 1581075720000, 'libelle': 'PRIX DU LITTORAL', 'libelleCourt': 'DU LITTORAL', 'montantPrix': 19000, 'parcours': 'Grande piste', 'distance': 2400, 'distanceUnit': 'METRE', 'corde': 'CORDE_GAUCHE', 'discipline': 'PLAT', 'specialite': 'PLAT', 'categorieParticularite': 'COURSE_A_CONDITIONS', 'conditionAge': 'QUATRE_ANS_ET_PLUS', 'conditionSexe':
# ...

# %%
get_data.get_course("07022020", 1, 1)
# Out:
# {'participants': [{'nom': "REBEL D'ANS",
#    'numPmu': 1,
#    'age': 5,
#    'sexe': 'HONGRES',
#    'race': 'PUR-SANG',
#    'statut': 'PARTANT',
#    'placeCorde': 3,
#    'oeilleres': 'SANS_OEILLERES',
#    'proprietaire': 'A.PHILIPPOT',
#    'entraineur': 'C.ESCUDER',
#    'driver': 'E.CIESLIK',
#    'driverChange': False,
#    'robe': {'code': '001', 'libelleCourt': 'ALEZAN', 'libelleLong': 'ALEZAN'},
#    'indicateurInedit': False,
#    'musique': '2p(19)1p2p4p1p2p8p5p5p',
#    'nombreCourses': 30,
#    'nombreVictoires': 4,
#    'nombrePlaces': 16,
#    'nombrePlacesSecond': 6,
#    'nombrePlacesTroisieme': 4,
#    'gainsParticipant': {'gainsCarriere': 8680000,
#     'gainsVictoires': 4050000,
#     'gainsPlace': 4630000,
#     'gainsAnneeEnCours': 400000,
#     'gainsAnneePrecedente': 2760000},
#    'handicapValeur': 38.0,
#    'nomPere': 'Legolas',
#    'nomMere': 'Hermei',
#    'nomPereMere': 'Snurge',
#    'ordreArrivee': 5,
#    'jumentPleine': False,
# ...
